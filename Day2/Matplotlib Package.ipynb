# %% [markdown]
# # Matplotlib

# %% [markdown]
# A Plot is a way of representing data visually. It can describe relationships between variables. Plots can give insight and information about the data that may not have been easily derived by looking at the data as a table.

# %%
import pandas as pd
import numpy as np
import pylab as plt
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting Linear and Quadratic Equations in Matplotlib

# %%
x = np.linspace(0, 2, 10)

plt.plot(x, x, 'o-', label='linear')
plt.plot(x, x ** 2, 'x-', label='quadratic')

plt.legend()
plt.title('Linear vs Quadratic progression')
plt.xlabel('Input')
plt.ylabel('Output');
plt.show()

# %%
import numpy as np
n = 256
X = np.linspace(-np.pi,np.pi,n,endpoint=True)
Y = np.sin(2*X)

plt.plot (X, Y+1, color='blue')
plt.plot (X, Y-1, color='red')
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['Modi ji', 'Kejriwal', 'Rahul', 'Mamta ji'] # list of all the labels
sizes = [38.4, 40.6, 20.7, 10.3] # values of all the labels(vote % of the leaders)
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral'] # list of colors
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90) # we use this fucntion to plot our pie plot by giving all the required parametrs.
plt.title('Vote % of leaders',size=20)
plt.legend(patches, labels, loc="best") # setting up the legend
plt.axis('equal')
plt.tight_layout()
plt.show() # this again shows us the plot

# %%
# Creatign seperate figures and axis
fig, ax = plt.subplots(figsize = (15, 9))
x=np.arange(0,3*np.pi,0.1)
y_s=np.sin(np.arange(0,3*np.pi,0.1))
y_c=np.cos(np.arange(0,3*np.pi,0.1))
# Accessign 2nd plot and customizing it.
plot2_1 = ax.plot(x,y_s, c = "Red")
plot2_1 = ax.plot(x,y_c, c = "green")

ax.set(title = "Sin Graph", xlabel = "X Values", ylabel="Sin Values")
ax.legend(("Sin", "Cos"), loc = "upper right")

plt.show()

# %%
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Set up a subplot grid that has height 2 and width 1,
plt.subplot(2, 1, 1) # setting the first such subplot as active.
## (height,width,plot no.)
plt.plot(x, y_sin)
plt.xlabel('x axis label') # this adds the name of x axis or label on the plot
plt.ylabel('y axis label') # this adds the name of y axis or label on the plot
plt.title('Sine')

plt.subplot(2, 1, 2) # Set the second subplot as active, and make the second plot.
plt.plot(x, y_cos)



# Show the figure.
plt.show()

# %%
# we will be ploting a bar plot the number of students studying programming languages

fig = plt.figure() 
ax = fig.add_axes([0,0,1,1]) 
langs = ['C', 'C++', 'Java', 'Python', 'PHP'] # these are the x axis values(the languages)
students = [23,17,35,29,12]  # y axis values (no. of students studying each language)
ax.bar(langs,students) # this plots a bar plot for langs and students
plt.title('students vs languages plot',size=20)
plt.xlabel('Languages',size=20)
plt.ylabel('no. of students',size=20)
plt.show()

# %% [markdown]
# ### Download the dataset : sales_data
# https://www.dropbox.com/s/g9nqd7gxbtm02yu/sales_data_sample.csv

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

df = pd.read_csv(r'C:\Users\PIYUSH\Downloads\sales_data.csv',engine='python')
df.head()

# plot YEAR ID
df['QUANTITYORDERED'].plot(kind = 'hist',bins = 10,rwidth = 0.8)

# display the plot
plt.show()

# %%
df['QUANTITYORDERED'].median()
# Out:
# 35.0

# %%
df['SALES'].max()
# Out:
# 14082.8

# %%
df.describe(include='all')
# Out:
#          ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count    2823.000000      2823.000000  2823.000000      2823.000000
# unique           NaN              NaN          NaN              NaN
# top              NaN              NaN          NaN              NaN
# freq             NaN              NaN          NaN              NaN
# mean    10258.725115        35.092809    83.658544         6.466171
# std        92.085478         9.741443    20.174277         4.225841
# min     10100.000000         6.000000    26.880000         1.000000
# 25%     10180.000000        27.000000    68.860000         3.000000
# 50%     10262.000000        35.000000    95.700000         6.000000
# 75%     10333.500000        43.000000   100.000000         9.000000
# max     10425.000000        97.000000   100.000000        18.000000
#
#                SALES        ORDERDATE   STATUS       QTR_ID     MONTH_ID  \
# count    2823.000000             2823     2823  2823.000000  2823.000000
# unique           NaN              252        6          NaN          NaN
# top              NaN  11/14/2003 0:00  Shipped          NaN          NaN
# freq             NaN               38     2617          NaN          NaN
# mean     3553.889072              NaN      NaN     2.717676     7.092455
# std      1841.865106              NaN      NaN     1.203878     3.656633
# min       482.130000              NaN      NaN     1.000000     1.000000
# 25%      2203.430000              NaN      NaN     2.000000     4.000000
# 50%      3184.800000              NaN      NaN     3.000000     8.000000
# 75%      4508.000000              NaN      NaN     4.000000    11.000000
# max     14082.800000              NaN      NaN     4.000000    12.000000
#
#            YEAR_ID  ...        ADDRESSLINE1  ADDRESSLINE2    CITY STATE  \
# count   2823.00000  ...                2823           302    2823  1337
# unique         NaN  ...                  92             9      73    16
# top            NaN  ...  C/ Moralzarzal, 86       Level 3  Madrid    CA
# freq           NaN  ...                 259            55     304   416
# mean    2003.81509  ...                 NaN           NaN     NaN   NaN
# std        0.69967  ...                 NaN           NaN     NaN   NaN
# min     2003.00000  ...                 NaN           NaN     NaN   NaN
# 25%     2003.00000  ...                 NaN           NaN     NaN   NaN
# 50%     2004.00000  ...                 NaN           NaN     NaN   NaN
# 75%     2004.00000  ...                 NaN           NaN     NaN   NaN
# max     2005.00000  ...                 NaN           NaN     NaN   NaN
#
#        POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# count        2747    2823      1749            2823             2823     2823
# unique         73      19         3              77               72        3
# top         28034     USA      EMEA          Freyre            Diego   Medium
# freq          259    1004      1407             259              259     1384
# mean          NaN     NaN       NaN             NaN              NaN      NaN
# std           NaN     NaN       NaN             NaN              NaN      NaN
# min           NaN     NaN       NaN             NaN              NaN      NaN
# 25%           NaN     NaN       NaN             NaN              NaN      NaN
# 50%           NaN     NaN       NaN             NaN              NaN      NaN
# 75%           NaN     NaN       NaN             NaN              NaN      NaN
# max           NaN     NaN       NaN             NaN              NaN      NaN
#
# [11 rows x 25 columns]

# %%
cnt=df.groupby('COUNTRY').sum()
cnt.plot(kind='bar',y='SALES')

# %%
cnt=df['COUNTRY'].value_counts().to_frame()
cnt.plot(kind='bar',y='COUNTRY')

# %%
df['QUANTITYORDERED'].plot(kind = 'density')

# display the plot
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt 

df = pd.read_csv(r'C:\Users\PIYUSH\Downloads\sales_data.csv',engine='python')
# plot all numerical columns
df.plot(kind = 'density',subplots = True, layout = (3,3), sharex = False, sharey = False)
# display the plot
plt.show()

# %%
df.plot(kind = 'box',subplots = True, layout = (3,3), sharex = False, sharey = False)
# display the plot
plt.show()

# %%
df.plot(kind = 'scatter',x = 'PRICEEACH',y = 'QUANTITYORDERED')
#display plot
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
new_df = df.groupby('PRODUCTLINE').sum()
new_df

# Draw a bar plot
new_df.plot(kind = 'bar',y = 'SALES')
plt.show()

# %%
new_df
# Out:
#                   ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# PRODUCTLINE
# Classic Cars          9918937            33992   84453.70             6233
# Motorcycles           3395505            11663   27472.19             1963
# Planes                3142556            10727   25012.72             2210
# Ships                 2399856             8127   19622.18             1591
# Trains                 789654             2712    5825.41              550
# Trucks and Buses      3087894            10777   26345.91             1873
# Vintage Cars          6225979            21069   47435.96             3834
#
#                        SALES  QTR_ID  MONTH_ID  YEAR_ID    MSRP
# PRODUCTLINE
# Classic Cars      3919615.66    2684      7003  1937661  115929
# Motorcycles       1166388.34     884      2275   663273   32130
# Planes             975003.57     800      2081   613199   27163
# Ships              714437.13     619      1622   468893   20154
# Trains             226243.47     209       549   154292    5620
# Trucks and Buses  1127789.84     837      2210   603143   30842
# Vintage Cars      1903150.84    1639      4282  1216309   52482

# %%
grouped_df = df.groupby(['YEAR_ID','PRODUCTLINE']).sum()
#plot scatter plot  
grouped_df.unstack().plot(kind = 'bar',y = 'SALES')

#display plot
plt.show()

# %%
grouped_df.unstack()
# Out:
#              ORDERNUMBER                                        \
# PRODUCTLINE Classic Cars Motorcycles   Planes    Ships  Trains
# YEAR_ID
# 2003             3720779     1106717   862535   822371  284301
# 2004             4545942     1686293  1656322  1182561  380664
# 2005             1652216      602495   623699   394924  124689
#
#                                           QUANTITYORDERED                     \
# PRODUCTLINE Trucks and Buses Vintage Cars    Classic Cars Motorcycles Planes
# YEAR_ID
# 2003                 1117147      2244249           12473        3739   2996
# 2004                 1461309      2921673           15418        5690   5524
# 2005                  509438      1060057            6101        2234   2207
#
#              ... MONTH_ID                                       MSRP  \
# PRODUCTLINE  ...   Trains Trucks and Buses Vintage Cars Classic Cars
# YEAR_ID      ...
# 2003         ...      226              896         1769        43634
# 2004         ...      290             1156         2212        53370
# 2005         ...       33              158          301        18925
#
#
# PRODUCTLINE Motorcycles Planes Ships Trains Trucks and Buses Vintage Cars
# YEAR_ID
# 2003              10662   7544  6975   2042            11290        19442
# 2004              15750  14274  9903   2698            14555        24301
# 2005               5718   5345  3276    880             4997         8739
#
# [3 rows x 56 columns]
